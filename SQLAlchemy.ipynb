# %% [markdown]
# # Kayak Hotels and Weather data - ETL Process

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
import re
import psycopg2
import boto3

from sqlalchemy import create_engine

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## ETL (Extract, Transform, Load)

# %% [markdown]
# ### Extract Raw Datasets

# %%
engine = create_engine(os.environ["DBURI"], pool_pre_ping=True)

# S3 files 
HOTELS_S3  = "s3://kayak-weather-hotel-data/Hotel_dataset_final_cityID.csv"
WEATHER_S3 = "s3://kayak-weather-hotel-data/Weather_dataset_final_cityID.csv"

# Build explicit storage options from env vars 
STORAGE = {
    "key": os.environ["AWS_ACCESS_KEY_ID"],
    "secret": os.environ["AWS_SECRET_ACCESS_KEY"],
    "client_kwargs": {"region_name": os.getenv("AWS_DEFAULT_REGION", "eu-west-3")},
}

hotels  = pd.read_csv(HOTELS_S3,  storage_options=STORAGE)
weather = pd.read_csv(WEATHER_S3, storage_options=STORAGE)

print("Hotels columns:", hotels.columns.tolist())
print("Weather columns:", weather.columns.tolist())
# Out:
# Hotels columns: ['City', 'Hotel Name', 'Rate', 'Number of Reviews', 'Neighborhood', 'Distance from Center', 'Description', 'Facilities', 'Address', 'Latitude', 'Longitude', 'Hotel URL', 'City_ID']
# Weather columns: ['dt', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase', 'summary', 'temp', 'feels_like', 'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_deg', 'wind_gust', 'weather', 'clouds', 'pop', 'uvi', 'rain', 'City', 'Latitude', 'Longitude', 'snow', 'day', 'min', 'max', 'night', 'eve', 'morn', 'average_min_temp', 'average_max_temp', 'rain_fall', 'avg_clouds', 'City_ID']

# %%
hotels.head()
# Out:
#               City                                      Hotel Name  \
# 0  Aix en Provence               Renaissance Aix-en-Provence Hotel
# 1  Aix en Provence                           Aquabella Hôtel & Spa
# 2  Aix en Provence   Hôtel Boutique Cézanne centre Aix-en-Provence
# 3  Aix en Provence                             Hôtel des Augustins
# 4  Aix en Provence  Grand Hôtel Roi René Aix - MGallery Collection
#
#                                         Rate  Number of Reviews  \
# 0  Scored 8.5\n8.5\nVery Good\n1,692 reviews             1692.0
# 1  Scored 8.6\n8.6\nExcellent\n1,485 reviews             1485.0
# 2  Scored 8.7\n8.7\nExcellent\n1,726 reviews             1726.0
# 3  Scored 8.4\n8.4\nVery Good\n2,246 reviews             2246.0
# 4  Scored 8.4\n8.4\nVery Good\n1,099 reviews             1099.0
#
#                                        Neighborhood  Distance from Center  \
# 0                                   Aix-en-Provence  0.6 km from downtown
# 1  Aix-en-Provence Historic Centre, Aix-en-Provence  0.6 km from downtown
# 2                                   Aix-en-Provence   300 m from downtown
# 3  Aix-en-Provence Historic Centre, Aix-en-Provence   150 m from downtown
# 4                                   Aix-en-Provence   500 m from downtown
#
#                                          Description  \
# 0  Located within a 10-minute walk of the center ...
# 1  Surrounded by a beautiful garden, Aquabella of...
# 2  This boutique design hotel is located in the c...
# 3  Located just of the famous Cours Mirabeau in t...
# 4  Located just a 5-minute walk from Cours Mirabe...
#
#                                           Facilities  \
# 0  2 swimming pools, Private Parking, Spa, Free W...
# 1  Outdoor swimming pool, Parking, Spa, Restauran...
# 2  Private Parking, Free Wifi, Family rooms, Non-...
# 3  Parking, Free Wifi, Family rooms, Non-smoking ...
# 4  Outdoor swimming pool, Private Parking, Free W...
#
#                                             Address   Latitude  Longitude  \
# 0                                   Aix-en-Provence  43.526240   5.438205
# 1  Aix-en-Provence Historic Centre, Aix-en-Provence  43.531264   5.445070
# 2                                   Aix-en-Provence  43.523562   5.445937
# 3  Aix-en-Provence Historic Centre, Aix-en-Provence  43.526887   5.447271
# 4                                   Aix-en-Provence  43.523325   5.449726
#
#                                            Hotel URL  City_ID
# 0  https://www.booking.com/hotel/fr/renaissance-a...       33
# 1  https://www.booking.com/hotel/fr/hotel-aquabel...       33
# 2  https://www.booking.com/hotel/fr/cezanne-aix-e...       33
# 3  https://www.booking.com/hotel/fr/les-augustins...       33
# 4  https://www.booking.com/hotel/fr/grand-mercure...       33

# %%
weather.head()
# Out:
#                           dt     sunrise      sunset    moonrise     moonset  \
# 0  2025-02-03 12:00:00+00:00  1738567966  1738602416  1738575420           0
# 1  2025-02-04 12:00:00+00:00  1738654281  1738688914  1738662900  1738626480
# 2  2025-02-05 12:00:00+00:00  1738740593  1738775413  1738750680  1738717980
# 3  2025-02-06 12:00:00+00:00  1738826905  1738861912  1738838880  1738809480
# 4  2025-02-07 12:00:00+00:00  1738913214  1738948412  1738927680  1738900680
#
#    moon_phase                                            summary  \
# 0        0.18                      There will be clear sky today
# 1        0.22            Expect a day of partly cloudy with rain
# 2        0.25    Expect a day of partly cloudy with clear spells
# 3        0.29  You can expect partly cloudy in the morning, w...
# 4        0.33  There will be clear sky until morning, then pa...
#
#                                                 temp  \
# 0  {'day': 7.86, 'min': 1.21, 'max': 8.62, 'night...
# 1  {'day': 9.43, 'min': 1.32, 'max': 11.07, 'nigh...
# 2  {'day': 9.74, 'min': 4.7, 'max': 10.13, 'night...
# 3  {'day': 7.97, 'min': 3.76, 'max': 8.47, 'night...
# 4  {'day': 4.6, 'min': 2.04, 'max': 4.6, 'night':...
#
#                                           feels_like  pressure  ...   min  \
# 0  {'day': 6.09, 'night': -0.26, 'eve': 5.08, 'mo...      1028  ...  1.21
# 1  {'day': 6.36, 'night': 6.91, 'eve': 5.43, 'mor...      1027  ...  1.32
# 2  {'day': 8.66, 'night': 2.12, 'eve': 4.17, 'mor...      1040  ...  4.70
# 3  {'day': 4.51, 'night': -0.41, 'eve': 0.61, 'mo...      1039  ...  3.76
# 4  {'day': 0.21, 'night': -1.53, 'eve': -0.93, 'm...      1026  ...  2.04
#
#      max  night   eve  morn average_min_temp  average_max_temp  rain_fall  \
# 0   8.62   2.94  7.09  1.26           2.8625             8.745   0.976667
# 1  11.07   8.90  7.98  1.32           2.8625             8.745   0.976667
# 2  10.13   4.70  6.47  5.05           2.8625             8.745   0.976667
# 3   8.47   4.29  5.01  4.13           2.8625             8.745   0.976667
# 4   4.60   2.56  3.35  2.04           2.8625             8.745   0.976667
#
#    avg_clouds  City_ID
# 0      55.875      276
# 1      55.875      276
# 2      55.875      276
# 3      55.875      276
# 4      55.875      276
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Transform Hotels Dataset

# %%
## Hotels data
hotels_clean = hotels.copy()

# Extract numeric rate from full reviews column 
hotels_clean["Clean_Rate"] = hotels_clean["Rate"].str.extract(r'(\d+\.\d+)').astype(float)

# Drop original rate column
hotels_clean = hotels_clean.drop(columns=["Rate"])

# Keep num reviews col as integer (no decimal place)
hotels_clean["Number of Reviews"] = hotels_clean["Number of Reviews"].astype(int)

# Replace spaces with underscores in all column names
hotels_clean.columns = [col.replace(" ", "_") for col in hotels_clean.columns]

hotels_clean.head()
# Out:
#               City                                      Hotel_Name  \
# 0  Aix en Provence               Renaissance Aix-en-Provence Hotel
# 1  Aix en Provence                           Aquabella Hôtel & Spa
# 2  Aix en Provence   Hôtel Boutique Cézanne centre Aix-en-Provence
# 3  Aix en Provence                             Hôtel des Augustins
# 4  Aix en Provence  Grand Hôtel Roi René Aix - MGallery Collection
#
#    Number_of_Reviews                                      Neighborhood  \
# 0               1692                                   Aix-en-Provence
# 1               1485  Aix-en-Provence Historic Centre, Aix-en-Provence
# 2               1726                                   Aix-en-Provence
# 3               2246  Aix-en-Provence Historic Centre, Aix-en-Provence
# 4               1099                                   Aix-en-Provence
#
#    Distance_from_Center                                        Description  \
# 0  0.6 km from downtown  Located within a 10-minute walk of the center ...
# 1  0.6 km from downtown  Surrounded by a beautiful garden, Aquabella of...
# 2   300 m from downtown  This boutique design hotel is located in the c...
# 3   150 m from downtown  Located just of the famous Cours Mirabeau in t...
# 4   500 m from downtown  Located just a 5-minute walk from Cours Mirabe...
#
#                                           Facilities  \
# 0  2 swimming pools, Private Parking, Spa, Free W...
# 1  Outdoor swimming pool, Parking, Spa, Restauran...
# 2  Private Parking, Free Wifi, Family rooms, Non-...
# 3  Parking, Free Wifi, Family rooms, Non-smoking ...
# 4  Outdoor swimming pool, Private Parking, Free W...
#
#                                             Address   Latitude  Longitude  \
# 0                                   Aix-en-Provence  43.526240   5.438205
# 1  Aix-en-Provence Historic Centre, Aix-en-Provence  43.531264   5.445070
# 2                                   Aix-en-Provence  43.523562   5.445937
# 3  Aix-en-Provence Historic Centre, Aix-en-Provence  43.526887   5.447271
# 4                                   Aix-en-Provence  43.523325   5.449726
#
#                                            Hotel_URL  City_ID  Clean_Rate
# 0  https://www.booking.com/hotel/fr/renaissance-a...       33         8.5
# 1  https://www.booking.com/hotel/fr/hotel-aquabel...       33         8.6
# 2  https://www.booking.com/hotel/fr/cezanne-aix-e...       33         8.7
# 3  https://www.booking.com/hotel/fr/les-augustins...       33         8.4
# 4  https://www.booking.com/hotel/fr/grand-mercure...       33         8.4

# %%
hotels_clean.to_csv("hotels_clean.csv", index=False)

# %% [markdown]
# ### Load Cleaned Hotels Dataset

# %%
import pandas as pd
from sqlalchemy import create_engine

# Credentials
USER = "jedha_user"
DBPASS = os.getenv("DBPASS")
DBHOST = os.getenv("DBHOST") 
DBNAME = "jedha-kayak"

# 1) Create SQLAlchemy engine
engine = create_engine(
    f"postgresql+psycopg2://{USER}:{DBPASS}@{DBHOST}/{DBNAME}",
    echo=True  # logs SQL for debugging
)

# 2) Load your cleaned dataframe into the DW
hotels_clean.to_sql(
    "hotel_clean_data",   # table name in DB
    engine,
    if_exists="replace",  
    index=False          
)

print("✅ Data loaded successfully into Postgres!")
# Out:
# 2025-08-19 22:23:42,682 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-08-19 22:23:42,684 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 22:23:42,712 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-08-19 22:23:42,712 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 22:23:42,729 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-08-19 22:23:42,730 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 22:23:42,746 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-19 22:23:42,780 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-08-19 22:23:42,782 INFO sqlalchemy.engine.Engine [generated in 0.00187s] {'table_name': 'hotel_clean_data', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-08-19 22:23:42,806 INFO sqlalchemy.engine.Engine
# CREATE TABLE hotel_clean_data (
# 	"City" TEXT,
# 	"Hotel_Name" TEXT,
# 	"Number_of_Reviews" BIGINT,
# 	"Neighborhood" TEXT,
# 	"Distance_from_Center" TEXT,
# 	"Description" TEXT,
# 	"Facilities" TEXT,
# 	"Address" TEXT,
# 	"Latitude" FLOAT(53),
# 	"Longitude" FLOAT(53),
# 	"Hotel_URL" TEXT,
# 	"City_ID" BIGINT,
# 	"Clean_Rate" FLOAT(53)
# )
#
#
# 2025-08-19 22:23:42,807 INFO sqlalchemy.engine.Engine [no key 0.00083s] {}
# 2025-08-19 22:23:42,847 INFO sqlalchemy.engine.Engine INSERT INTO hotel_clean_data ("City", "Hotel_Name", "Number_of_Reviews", "Neighborhood", "Distance_from_Center", "Description", "Facilities", "Address", "Latitude", "Longitude", "Hotel_URL", "City_ID", "Clean_Rate") VALUES (%(City__0)s, %(Hotel_Name_ ... 33316 characters truncated ... s, %(Latitude__124)s, %(Longitude__124)s, %(Hotel_URL__124)s, %(City_ID__124)s, %(Clean_Rate__124)s)
# 2025-08-19 22:23:42,848 INFO sqlalchemy.engine.Engine [generated in 0.00159s (insertmanyvalues) 1/1 (unordered)] {'Latitude__0': 43.52624, 'City_ID__0': 33, 'Neighborhood__0': 'Aix-en-Provence', 'City__0': 'Aix en Provence', 'Longitude__0': 5.438205, 'Hotel_Name__0': 'Renaissance Aix-en-Provence Hotel', 'Facilities__0': '2 swimming pools, Private Parking, Spa, Free Wifi, Family rooms, 2 restaurants, Fitness center, Tea/Coffee Maker in All Rooms, Bar, Good Breakfast', 'Number_of_Reviews__0': 1692, 'Hotel_URL__0': 'https://www.booking.com/hotel/fr/renaissance-aix-en-provence.html?aid=304142&label=gen173nr-10CAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYATO ... (153 characters truncated) ... s=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=ht_id%3D204&srpvid=52a986e0789f0695&srepoch=1755285061&from=searchresults', 'Clean_Rate__0': 8.5, 'Distance_from_Center__0': '0.6 km from downtown', 'Description__0': 'Located within a 10-minute walk of the center of Aix-en-Provence, Renaissance Aix-en-Provence Hotel features free access to a spa with a heated indoo ... (432 characters truncated) ...  mi away, bowling 0.6 mi away or horse riding 1.2 mi away. The Grand Theater is 656 feet away. Marseille-Marignane Airport is a 25-minute drive away.', 'Address__0': 'Aix-en-Provence', 'Latitude__1': 43.531264, 'City_ID__1': 33, 'Neighborhood__1': 'Aix-en-Provence Historic Centre, Aix-en-Provence', 'City__1': 'Aix en Provence', 'Longitude__1': 5.44507, 'Hotel_Name__1': 'Aquabella Hôtel & Spa', 'Facilities__1': 'Outdoor swimming pool, Parking, Spa, Restaurant, Fitness center, Non-smoking rooms, Facilities for disabled guests, Bar, Excellent Breakfast', 'Number_of_Reviews__1': 1485, 'Hotel_URL__1': 'https://www.booking.com/hotel/fr/hotel-aquabella.html?aid=304142&label=gen173nr-10CAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYATO4AQfIAQzYAQP ... (141 characters truncated) ... s=1&group_children=0&req_children=0&hpos=2&hapos=2&sr_order=popularity&nflt=ht_id%3D204&srpvid=52a986e0789f0695&srepoch=1755285076&from=searchresults', 'Clean_Rate__1': 8.6, 'Distance_from_Center__1': '0.6 km from downtown', 'Description__1': 'Surrounded by a beautiful garden, Aquabella offers Provencal-style rooms and guests have free access to the spa. It is located in central Aix-en-Prov ... (367 characters truncated) ...  There is also a Kneipp shower and ice fountain.\n\nGuests will find public parking just 164 feet away from the property, available at an extra cost.', 'Address__1': 'Aix-en-Provence Historic Centre, Aix-en-Provence', 'Latitude__2': 43.523562, 'City_ID__2': 33, 'Neighborhood__2': 'Aix-en-Provence', 'City__2': 'Aix en Provence', 'Longitude__2': 5.445937, 'Hotel_Name__2': 'Hôtel Boutique Cézanne centre Aix-en-Provence', 'Facilities__2': 'Private Parking, Free Wifi, Family rooms, Non-smoking rooms, Facilities for disabled guests, Airport shuttle, Room service, Tea/Coffee Maker in All Rooms, Bar, Excellent Breakfast', 'Number_of_Reviews__2': 1726, 'Hotel_URL__2': 'https://www.booking.com/hotel/fr/cezanne-aix-en-provence.html?aid=304142&label=gen173nr-10CAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYATO4AQf ... (149 characters truncated) ... s=1&group_children=0&req_children=0&hpos=3&hapos=3&sr_order=popularity&nflt=ht_id%3D204&srpvid=52a986e0789f0695&srepoch=1755285082&from=searchresults', 'Clean_Rate__2': 8.7, 'Distance_from_Center__2': '300 m from downtown', 'Description__2': 'This boutique design hotel is located in the center of Aix-en-Provence and offers 55 rooms. If features a terrace and a lounge.\n\nThe air-conditione ... (850 characters truncated) ... ude satellite TV with more than 50 channels and some have views over the town.\n\nPrivate secured parking is available on site for an additional fee.', 'Address__2': 'Aix-en-Provence', 'Latitude__3': 43.526887, 'City_ID__3': 33, 'Neighborhood__3': 'Aix-en-Provence Historic Centre, Aix-en-Provence', 'City__3': 'Aix en Provence', 'Longitude__3': 5.447271, 'Hotel_Nam ...
# 2025-08-19 22:23:42,942 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Data loaded successfully into Postgres!

# %% [markdown]
# ### Transform Weather Dataset

# %%
## Weather data

# Show all columns
pd.set_option("display.max_columns", None)

weather.head()
# Out:
#                           dt     sunrise      sunset    moonrise     moonset  \
# 0  2025-02-03 12:00:00+00:00  1738567966  1738602416  1738575420           0
# 1  2025-02-04 12:00:00+00:00  1738654281  1738688914  1738662900  1738626480
# 2  2025-02-05 12:00:00+00:00  1738740593  1738775413  1738750680  1738717980
# 3  2025-02-06 12:00:00+00:00  1738826905  1738861912  1738838880  1738809480
# 4  2025-02-07 12:00:00+00:00  1738913214  1738948412  1738927680  1738900680
#
#    moon_phase                                            summary  \
# 0        0.18                      There will be clear sky today
# 1        0.22            Expect a day of partly cloudy with rain
# 2        0.25    Expect a day of partly cloudy with clear spells
# 3        0.29  You can expect partly cloudy in the morning, w...
# 4        0.33  There will be clear sky until morning, then pa...
#
#                                                 temp  \
# 0  {'day': 7.86, 'min': 1.21, 'max': 8.62, 'night...
# 1  {'day': 9.43, 'min': 1.32, 'max': 11.07, 'nigh...
# 2  {'day': 9.74, 'min': 4.7, 'max': 10.13, 'night...
# 3  {'day': 7.97, 'min': 3.76, 'max': 8.47, 'night...
# 4  {'day': 4.6, 'min': 2.04, 'max': 4.6, 'night':...
#
#                                           feels_like  pressure  humidity  \
# 0  {'day': 6.09, 'night': -0.26, 'eve': 5.08, 'mo...      1028        75
# 1  {'day': 6.36, 'night': 6.91, 'eve': 5.43, 'mor...      1027        81
# 2  {'day': 8.66, 'night': 2.12, 'eve': 4.17, 'mor...      1040        70
# 3  {'day': 4.51, 'night': -0.41, 'eve': 0.61, 'mo...      1039        67
# 4  {'day': 0.21, 'night': -1.53, 'eve': -0.93, 'm...      1026        72
#
#    dew_point  wind_speed  wind_deg  wind_gust  \
# 0       3.71        3.51       167       4.14
# 1       6.13        6.95       209      10.61
# 2       4.26        3.56       351       5.74
# 3       2.13        7.03        47      13.51
# 4      -0.21        6.84        48      12.85
#
#                                              weather  clouds   pop   uvi  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...       4  0.00  1.37
# 1  [{'id': 500, 'main': 'Rain', 'description': 'l...       1  1.00  1.30
# 2  [{'id': 803, 'main': 'Clouds', 'description': ...      70  0.76  1.24
# 3  [{'id': 803, 'main': 'Clouds', 'description': ...      55  0.00  1.09
# 4  [{'id': 803, 'main': 'Clouds', 'description': ...      83  0.00  1.37
#
#    rain               City  Latitude  Longitude  snow   day   min    max  \
# 0   NaN  Mont Saint Michel     48.64      -1.51   NaN  7.86  1.21   8.62
# 1  0.59  Mont Saint Michel     48.64      -1.51   NaN  9.43  1.32  11.07
# 2   NaN  Mont Saint Michel     48.64      -1.51   NaN  9.74  4.70  10.13
# 3   NaN  Mont Saint Michel     48.64      -1.51   NaN  7.97  3.76   8.47
# 4   NaN  Mont Saint Michel     48.64      -1.51   NaN  4.60  2.04   4.60
#
#    night   eve  morn  average_min_temp  average_max_temp  rain_fall  \
# 0   2.94  7.09  1.26            2.8625             8.745   0.976667
# 1   8.90  7.98  1.32            2.8625             8.745   0.976667
# 2   4.70  6.47  5.05            2.8625             8.745   0.976667
# 3   4.29  5.01  4.13            2.8625             8.745   0.976667
# 4   2.56  3.35  2.04            2.8625             8.745   0.976667
#
#    avg_clouds  City_ID
# 0      55.875      276
# 1      55.875      276
# 2      55.875      276
# 3      55.875      276
# 4      55.875      276

# %%
weather_clean = weather.copy()

# Convert date column (object) to datetime for easier manipulation
weather_clean["dt"] = pd.to_datetime(weather_clean["dt"], errors="coerce", dayfirst=True)
weather_clean = weather_clean.rename(columns={"dt": "Date"})


# Keep only columns of interest
keep_cols = [
    "Date", "City_ID", "City", "Latitude", "Longitude",
    "summary", 
    #"weather",
    #"temp", "feels_like", #already extracted previously
    "min", "max",
    "average_min_temp", "average_max_temp",
    "pressure", "humidity", "dew_point",
    "wind_speed", "wind_deg", "wind_gust",
    "clouds", "avg_clouds",
    "pop", "rain", "rain_fall", "snow",
    "uvi"
]

# Keep only those columns that exist in df
weather_clean = weather_clean[[col for col in keep_cols if col in weather_clean.columns]].copy()

# Capitalize first letter of each column name
def clean_col(col):
    col = col.replace("_", " ").title().replace(" ", "_")
    # Fix common acronyms
    col = col.replace("Id", "ID").replace("Uvi", "UVI")
    return col

weather_clean.columns = [clean_col(c) for c in weather_clean.columns]

weather_clean.head()
# Out:
#                        Date  City_ID               City  Latitude  Longitude  \
# 0 2025-03-02 12:00:00+00:00      276  Mont Saint Michel     48.64      -1.51
# 1 2025-04-02 12:00:00+00:00      276  Mont Saint Michel     48.64      -1.51
# 2 2025-05-02 12:00:00+00:00      276  Mont Saint Michel     48.64      -1.51
# 3 2025-06-02 12:00:00+00:00      276  Mont Saint Michel     48.64      -1.51
# 4 2025-07-02 12:00:00+00:00      276  Mont Saint Michel     48.64      -1.51
#
#                                              Summary   Min    Max  \
# 0                      There will be clear sky today  1.21   8.62
# 1            Expect a day of partly cloudy with rain  1.32  11.07
# 2    Expect a day of partly cloudy with clear spells  4.70  10.13
# 3  You can expect partly cloudy in the morning, w...  3.76   8.47
# 4  There will be clear sky until morning, then pa...  2.04   4.60
#
#    Average_Min_Temp  Average_Max_Temp  ...  Wind_Speed  Wind_Deg  Wind_Gust  \
# 0            2.8625             8.745  ...        3.51       167       4.14
# 1            2.8625             8.745  ...        6.95       209      10.61
# 2            2.8625             8.745  ...        3.56       351       5.74
# 3            2.8625             8.745  ...        7.03        47      13.51
# 4            2.8625             8.745  ...        6.84        48      12.85
#
#    Clouds  Avg_Clouds   Pop  Rain  Rain_Fall  Snow   UVI
# 0       4      55.875  0.00   NaN   0.976667   NaN  1.37
# 1       1      55.875  1.00  0.59   0.976667   NaN  1.30
# 2      70      55.875  0.76   NaN   0.976667   NaN  1.24
# 3      55      55.875  0.00   NaN   0.976667   NaN  1.09
# 4      83      55.875  0.00   NaN   0.976667   NaN  1.37
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Load Cleaned Weather Dataset

# %%
#Load cleaned dataframe into the DW
weather_clean.to_sql(
    "weather_clean_data",   # table name in DB
    engine,
    if_exists="replace",  
    index=False          
)

print("✅ Data loaded successfully into Postgres!")
# Out:
# 2025-08-19 22:27:02,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-19 22:27:02,676 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-08-19 22:27:02,678 INFO sqlalchemy.engine.Engine [cached since 199.9s ago] {'table_name': 'weather_clean_data', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-08-19 22:27:02,709 INFO sqlalchemy.engine.Engine
# CREATE TABLE weather_clean_data (
# 	"Date" TIMESTAMP WITH TIME ZONE,
# 	"City_ID" BIGINT,
# 	"City" TEXT,
# 	"Latitude" FLOAT(53),
# 	"Longitude" FLOAT(53),
# 	"Summary" TEXT,
# 	"Min" FLOAT(53),
# 	"Max" FLOAT(53),
# 	"Average_Min_Temp" FLOAT(53),
# 	"Average_Max_Temp" FLOAT(53),
# 	"Pressure" BIGINT,
# 	"Humidity" BIGINT,
# 	"Dew_Point" FLOAT(53),
# 	"Wind_Speed" FLOAT(53),
# 	"Wind_Deg" BIGINT,
# 	"Wind_Gust" FLOAT(53),
# 	"Clouds" BIGINT,
# 	"Avg_Clouds" FLOAT(53),
# 	"Pop" FLOAT(53),
# 	"Rain" FLOAT(53),
# 	"Rain_Fall" FLOAT(53),
# 	"Snow" FLOAT(53),
# 	"UVI" FLOAT(53)
# )
#
#
# 2025-08-19 22:27:02,710 INFO sqlalchemy.engine.Engine [no key 0.00085s] {}
# 2025-08-19 22:27:02,778 INFO sqlalchemy.engine.Engine INSERT INTO weather_clean_data ("Date", "City_ID", "City", "Latitude", "Longitude", "Summary", "Min", "Max", "Average_Min_Temp", "Average_Max_Temp", "Pressure", "Humidity", "Dew_Point", "Wind_Speed", "Wind_Deg", "Wind_Gust", "Clouds", "Avg_Clouds", " ... 115857 characters truncated ... , %(Avg_Clouds__279)s, %(Pop__279)s, %(Rain__279)s, %(Rain_Fall__279)s, %(Snow__279)s, %(UVI__279)s)
# 2025-08-19 22:27:02,778 INFO sqlalchemy.engine.Engine [generated in 0.01129s (insertmanyvalues) 1/1 (unordered)] {'Latitude__0': 48.64, 'Max__0': 8.62, 'Avg_Clouds__0': 55.875, 'Date__0': datetime.datetime(2025, 3, 2, 12, 0, tzinfo=datetime.timezone.utc), 'UVI__0': 1.37, 'Min__0': 1.21, 'Rain__0': None, 'Wind_Deg__0': 167, 'Wind_Gust__0': 4.14, 'Rain_Fall__0': 0.9766666666666666, 'City_ID__0': 276, 'Clouds__0': 4, 'Snow__0': None, 'Pop__0': 0.0, 'Longitude__0': -1.51, 'Humidity__0': 75, 'Summary__0': 'There will be clear sky today', 'Pressure__0': 1028, 'Average_Min_Temp__0': 2.8625000000000003, 'Average_Max_Temp__0': 8.745, 'Wind_Speed__0': 3.51, 'City__0': 'Mont Saint Michel', 'Dew_Point__0': 3.71, 'Latitude__1': 48.64, 'Max__1': 11.07, 'Avg_Clouds__1': 55.875, 'Date__1': datetime.datetime(2025, 4, 2, 12, 0, tzinfo=datetime.timezone.utc), 'UVI__1': 1.3, 'Min__1': 1.32, 'Rain__1': 0.59, 'Wind_Deg__1': 209, 'Wind_Gust__1': 10.61, 'Rain_Fall__1': 0.9766666666666666, 'City_ID__1': 276, 'Clouds__1': 1, 'Snow__1': None, 'Pop__1': 1.0, 'Longitude__1': -1.51, 'Humidity__1': 81, 'Summary__1': 'Expect a day of partly cloudy with rain', 'Pressure__1': 1027, 'Average_Min_Temp__1': 2.8625000000000003, 'Average_Max_Temp__1': 8.745, 'Wind_Speed__1': 6.95, 'City__1': 'Mont Saint Michel', 'Dew_Point__1': 6.13, 'Latitude__2': 48.64, 'Max__2': 10.13, 'Avg_Clouds__2': 55.875, 'Date__2': datetime.datetime(2025, 5, 2, 12, 0, tzinfo=datetime.timezone.utc) ... 6340 parameters truncated ... 'Average_Max_Temp__277': 8.383750000000001, 'Wind_Speed__277': 2.14, 'City__277': 'La Rochelle', 'Dew_Point__277': 1.2, 'Latitude__278': 46.16, 'Max__278': 10.01, 'Avg_Clouds__278': 60.875, 'Date__278': datetime.datetime(2025, 9, 2, 12, 0, tzinfo=datetime.timezone.utc), 'UVI__278': 2.0, 'Min__278': 3.5, 'Rain__278': None, 'Wind_Deg__278': 62, 'Wind_Gust__278': 12.72, 'Rain_Fall__278': 2.5500000000000003, 'City_ID__278': 236, 'Clouds__278': 51, 'Snow__278': None, 'Pop__278': 0.0, 'Longitude__278': -1.15, 'Humidity__278': 80, 'Summary__278': 'There will be partly cloudy today', 'Pressure__278': 1033, 'Average_Min_Temp__278': 4.215, 'Average_Max_Temp__278': 8.383750000000001, 'Wind_Speed__278': 6.45, 'City__278': 'La Rochelle', 'Dew_Point__278': 5.82, 'Latitude__279': 46.16, 'Max__279': 10.24, 'Avg_Clouds__279': 60.875, 'Date__279': datetime.datetime(2025, 10, 2, 12, 0, tzinfo=datetime.timezone.utc), 'UVI__279': 2.0, 'Min__279': 3.73, 'Rain__279': None, 'Wind_Deg__279': 70, 'Wind_Gust__279': 12.05, 'Rain_Fall__279': 2.5500000000000003, 'City_ID__279': 236, 'Clouds__279': 65, 'Snow__279': None, 'Pop__279': 0.0, 'Longitude__279': -1.15, 'Humidity__279': 73, 'Summary__279': 'There will be partly cloudy today', 'Pressure__279': 1028, 'Average_Min_Temp__279': 4.215, 'Average_Max_Temp__279': 8.383750000000001, 'Wind_Speed__279': 6.31, 'City__279': 'La Rochelle', 'Dew_Point__279': 4.14}
# 2025-08-19 22:27:02,845 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Data loaded successfully into Postgres!

# %% [markdown]
# ### Merge Clean Hotels + Weather Datasets

# %%
# Merge the two datasets by City_ID

hotel_weather_data = pd.merge(
    hotels_clean,
    weather_clean,
    on="City_ID",
    how="inner"  #only keep rows with matching City_IDs
)

print("Merged dataset shape:", hotel_weather_data.shape)
# Out:
# Merged dataset shape: (1000, 35)

# %%
hotel_weather_data.head()
# Out:
#             City_x                         Hotel_Name  Number_of_Reviews  \
# 0  Aix en Provence  Renaissance Aix-en-Provence Hotel               1692
# 1  Aix en Provence  Renaissance Aix-en-Provence Hotel               1692
# 2  Aix en Provence  Renaissance Aix-en-Provence Hotel               1692
# 3  Aix en Provence  Renaissance Aix-en-Provence Hotel               1692
# 4  Aix en Provence  Renaissance Aix-en-Provence Hotel               1692
#
#       Neighborhood  Distance_from_Center  \
# 0  Aix-en-Provence  0.6 km from downtown
# 1  Aix-en-Provence  0.6 km from downtown
# 2  Aix-en-Provence  0.6 km from downtown
# 3  Aix-en-Provence  0.6 km from downtown
# 4  Aix-en-Provence  0.6 km from downtown
#
#                                          Description  \
# 0  Located within a 10-minute walk of the center ...
# 1  Located within a 10-minute walk of the center ...
# 2  Located within a 10-minute walk of the center ...
# 3  Located within a 10-minute walk of the center ...
# 4  Located within a 10-minute walk of the center ...
#
#                                           Facilities          Address  \
# 0  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 1  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 2  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 3  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 4  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
#
#    Latitude_x  Longitude_x                                          Hotel_URL  \
# 0    43.52624     5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 1    43.52624     5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 2    43.52624     5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 3    43.52624     5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 4    43.52624     5.438205  https://www.booking.com/hotel/fr/renaissance-a...
#
#    City_ID  Clean_Rate                      Date           City_y  Latitude_y  \
# 0       33         8.5 2025-03-02 11:00:00+00:00  Aix en Provence       43.53
# 1       33         8.5 2025-04-02 11:00:00+00:00  Aix en Provence       43.53
# 2       33         8.5 2025-05-02 11:00:00+00:00  Aix en Provence       43.53
# 3       33         8.5 2025-06-02 11:00:00+00:00  Aix en Provence       43.53
# 4       33         8.5 2025-07-02 11:00:00+00:00  Aix en Provence       43.53
#
#    Longitude_y                                            Summary   Min  \
# 0         5.45  There will be partly cloudy until morning, the...  6.20
# 1         5.45    Expect a day of partly cloudy with clear spells  6.24
# 2         5.45    Expect a day of partly cloudy with clear spells  5.80
# 3         5.45                      There will be clear sky today  5.99
# 4         5.45  There will be clear sky until morning, then pa...  5.84
#
#      Max  Average_Min_Temp  Average_Max_Temp  Pressure  Humidity  Dew_Point  \
# 0  14.63              6.76          12.96125      1022        48       1.00
# 1  13.58              6.76          12.96125      1026        38      -1.77
# 2  13.91              6.76          12.96125      1031        43      -0.97
# 3  13.79              6.76          12.96125      1028        41      -0.70
# 4  10.21              6.76          12.96125      1022        64       3.47
#
#    Wind_Speed  Wind_Deg  Wind_Gust  Clouds  Avg_Clouds   Pop  Rain  Rain_Fall  \
# 0        1.96       302       2.68       0       54.25  0.00   NaN      0.595
# 1        2.31       234       2.17      41       54.25  0.00   NaN      0.595
# 2        1.72       290       2.02       0       54.25  0.00   NaN      0.595
# 3        2.60       245       2.35       0       54.25  0.00   NaN      0.595
# 4        7.53       107      12.79      96       54.25  0.02   NaN      0.595
#
#    Snow   UVI
# 0   NaN  1.97
# 1   NaN  1.79
# 2   NaN  1.88
# 3   NaN  1.97
# 4   NaN  1.74

# %% [markdown]
# ### Tansform Merged Dataset

# %%
# Final cleaning

## Drop duplicate city/location columns 
cols_to_drop = ["City_y", "Latitude_y", "Longitude_y"]
hotel_weather_data = hotel_weather_data.drop(columns=[c for c in cols_to_drop if c in hotel_weather_data.columns])

## Rename _x / _y leftovers
hotel_weather_data = hotel_weather_data.rename(columns={
    "City_x": "City",
    "Latitude_x": "Latitude",
    "Longitude_x": "Longitude",
    "Clean_Rate": "Rate",
    "Date": "Weather_Date",
    "Summary": "Weather_Summary",
    "Min": "Min_Temp",
    "Max": "Max_Temp"
})

# Ensure City_ID is first
cols = ["City_ID"] + [c for c in hotel_weather_data.columns if c != "City_ID"]
hotel_weather_data = hotel_weather_data[cols]

hotel_weather_data.head()
# Out:
#    City_ID             City                         Hotel_Name  \
# 0       33  Aix en Provence  Renaissance Aix-en-Provence Hotel
# 1       33  Aix en Provence  Renaissance Aix-en-Provence Hotel
# 2       33  Aix en Provence  Renaissance Aix-en-Provence Hotel
# 3       33  Aix en Provence  Renaissance Aix-en-Provence Hotel
# 4       33  Aix en Provence  Renaissance Aix-en-Provence Hotel
#
#    Number_of_Reviews     Neighborhood  Distance_from_Center  \
# 0               1692  Aix-en-Provence  0.6 km from downtown
# 1               1692  Aix-en-Provence  0.6 km from downtown
# 2               1692  Aix-en-Provence  0.6 km from downtown
# 3               1692  Aix-en-Provence  0.6 km from downtown
# 4               1692  Aix-en-Provence  0.6 km from downtown
#
#                                          Description  \
# 0  Located within a 10-minute walk of the center ...
# 1  Located within a 10-minute walk of the center ...
# 2  Located within a 10-minute walk of the center ...
# 3  Located within a 10-minute walk of the center ...
# 4  Located within a 10-minute walk of the center ...
#
#                                           Facilities          Address  \
# 0  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 1  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 2  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 3  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 4  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
#
#    Latitude  ...  Wind_Speed Wind_Deg  Wind_Gust Clouds Avg_Clouds   Pop  \
# 0  43.52624  ...        1.96      302       2.68      0      54.25  0.00
# 1  43.52624  ...        2.31      234       2.17     41      54.25  0.00
# 2  43.52624  ...        1.72      290       2.02      0      54.25  0.00
# 3  43.52624  ...        2.60      245       2.35      0      54.25  0.00
# 4  43.52624  ...        7.53      107      12.79     96      54.25  0.02
#
#    Rain  Rain_Fall  Snow   UVI
# 0   NaN      0.595   NaN  1.97
# 1   NaN      0.595   NaN  1.79
# 2   NaN      0.595   NaN  1.88
# 3   NaN      0.595   NaN  1.97
# 4   NaN      0.595   NaN  1.74
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Load Merged Dataset

# %%
# Load merged cleaned dataframe into the DW
hotel_weather_data.to_sql(
    "hotel_weather_data",   # table name in DB
    engine,
    if_exists="replace",  
    index=False          
)

print("✅ Data loaded successfully into Postgres!")
# Out:
# 2025-08-19 12:12:15,245 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-08-19 12:12:15,247 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 12:12:15,280 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-08-19 12:12:15,281 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 12:12:15,307 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-08-19 12:12:15,308 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 12:12:15,330 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-19 12:12:15,355 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-08-19 12:12:15,356 INFO sqlalchemy.engine.Engine [generated in 0.00121s] {'table_name': 'hotel_weather_data', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-08-19 12:12:15,395 INFO sqlalchemy.engine.Engine
# CREATE TABLE hotel_weather_data (
# 	"City_ID" BIGINT,
# 	"City" TEXT,
# 	"Hotel_Name" TEXT,
# 	"Number_of_Reviews" BIGINT,
# 	"Neighborhood" TEXT,
# 	"Distance_from_Center" TEXT,
# 	"Description" TEXT,
# 	"Facilities" TEXT,
# 	"Address" TEXT,
# 	"Latitude" FLOAT(53),
# 	"Longitude" FLOAT(53),
# 	"Hotel_URL" TEXT,
# 	"Rate" FLOAT(53),
# 	"Weather_Date" TIMESTAMP WITH TIME ZONE,
# 	"Weather_Summary" TEXT,
# 	"Min_Temp" FLOAT(53),
# 	"Max_Temp" FLOAT(53),
# 	"Average_Min_Temp" FLOAT(53),
# 	"Average_Max_Temp" FLOAT(53),
# 	"Pressure" BIGINT,
# 	"Humidity" BIGINT,
# 	"Dew_Point" FLOAT(53),
# 	"Wind_Speed" FLOAT(53),
# 	"Wind_Deg" BIGINT,
# 	"Wind_Gust" FLOAT(53),
# 	"Clouds" BIGINT,
# 	"Avg_Clouds" FLOAT(53),
# 	"Pop" FLOAT(53),
# 	"Rain" FLOAT(53),
# 	"Rain_Fall" FLOAT(53),
# 	"Snow" FLOAT(53),
# 	"UVI" FLOAT(53)
# )
#
#
# 2025-08-19 12:12:15,396 INFO sqlalchemy.engine.Engine [no key 0.00078s] {}
# 2025-08-19 12:12:15,478 INFO sqlalchemy.engine.Engine INSERT INTO hotel_weather_data ("City_ID", "City", "Hotel_Name", "Number_of_Reviews", "Neighborhood", "Distance_from_Center", "Description", "Facilities", "Address", "Latitude", "Longitude", "Hotel_URL", "Rate", "Weather_Date", "Weather_Summary", "Mi ... 644589 characters truncated ... , %(Avg_Clouds__999)s, %(Pop__999)s, %(Rain__999)s, %(Rain_Fall__999)s, %(Snow__999)s, %(UVI__999)s)
# 2025-08-19 12:12:15,479 INFO sqlalchemy.engine.Engine [generated in 0.02267s (insertmanyvalues) 1/1 (unordered)] {'Rain_Fall__0': 0.595, 'Hotel_URL__0': 'https://www.booking.com/hotel/fr/renaissance-aix-en-provence.html?aid=304142&label=gen173nr-10CAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYATO ... (153 characters truncated) ... s=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=ht_id%3D204&srpvid=52a986e0789f0695&srepoch=1755285061&from=searchresults', 'City__0': 'Aix en Provence', 'Pressure__0': 1022, 'Clouds__0': 0, 'Pop__0': 0.0, 'Facilities__0': '2 swimming pools, Private Parking, Spa, Free Wifi, Family rooms, 2 restaurants, Fitness center, Tea/Coffee Maker in All Rooms, Bar, Good Breakfast', 'Rate__0': 8.5, 'Average_Max_Temp__0': 12.96125, 'Wind_Deg__0': 302, 'City_ID__0': 33, 'Latitude__0': 43.52624, 'Rain__0': None, 'Longitude__0': 5.438205, 'Hotel_Name__0': 'Renaissance Aix-en-Provence Hotel', 'Snow__0': None, 'Average_Min_Temp__0': 6.76, 'Weather_Summary__0': 'There will be partly cloudy until morning, then clearing', 'Address__0': 'Aix-en-Provence', 'Avg_Clouds__0': 54.25, 'Max_Temp__0': 14.63, 'Weather_Date__0': datetime.datetime(2025, 3, 2, 11, 0, tzinfo=datetime.timezone.utc), 'Number_of_Reviews__0': 1692, 'Neighborhood__0': 'Aix-en-Provence', 'Humidity__0': 48, 'Dew_Point__0': 1.0, 'Distance_from_Center__0': '0.6 km from downtown', 'Description__0': 'Located within a 10-minute walk of the center of Aix-en-Provence, Renaissance Aix-en-Provence Hotel features free access to a spa with a heated indoo ... (432 characters truncated) ...  mi away, bowling 0.6 mi away or horse riding 1.2 mi away. The Grand Theater is 656 feet away. Marseille-Marignane Airport is a 25-minute drive away.', 'Wind_Speed__0': 1.96, 'UVI__0': 1.97, 'Wind_Gust__0': 2.68, 'Min_Temp__0': 6.2, 'Rain_Fall__1': 0.595, 'Hotel_URL__1': 'https://www.booking.com/hotel/fr/renaissance-aix-en-provence.html?aid=304142&label=gen173nr-10CAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYATO ... (153 characters truncated) ... s=1&group_children=0&req_children=0&hpos=1&hapos=1&sr_order=popularity&nflt=ht_id%3D204&srpvid=52a986e0789f0695&srepoch=1755285061&from=searchresults', 'City__1': 'Aix en Provence', 'Pressure__1': 1026, 'Clouds__1': 41, 'Pop__1': 0.0, 'Facilities__1': '2 swimming pools, Private Parking, Spa, Free Wifi, Family rooms, 2 restaurants, Fitness center, Tea/Coffee Maker in All Rooms, Bar, Good Breakfast', 'Rate__1': 8.5, 'Average_Max_Temp__1': 12.96125, 'Wind_Deg__1': 234, 'City_ID__1': 33, 'Latitude__1': 43.52624, 'Rain__1': None, 'Longitude__1': 5.438205, 'Hotel_Name__1': 'Renaissance Aix-en-Provence Hotel', 'Snow__1': None, 'Average_Min_Temp__1': 6.76, 'Weather_Summary__1': 'Expect a day of partly cloudy with clear spells' ... 31900 parameters truncated ... 'Hotel_Name__998': 'Appart Hotel Odalys City Toulouse Colombélie', 'Snow__998': None, 'Average_Min_Temp__998': 3.87, 'Weather_Summary__998': 'There will be partly cloudy today', 'Address__998': 'Toulouse City-Centre, Toulouse', 'Avg_Clouds__998': 40.375, 'Max_Temp__998': 10.75, 'Weather_Date__998': datetime.datetime(2025, 9, 2, 12, 0, tzinfo=datetime.timezone.utc), 'Number_of_Reviews__998': 3351, 'Neighborhood__998': 'Toulouse City-Centre, Toulouse', 'Humidity__998': 69, 'Dew_Point__998': 3.39, 'Distance_from_Center__998': '0.9 km from downtown', 'Description__998': 'Located in Toulouse, just 0.6 mi from the famous Place du Capitole, Appart Hotel Odalys City Toulouse Colombélie offers self-catering accommodations. ... (422 characters truncated) ... se Expo is 2.5 mi away.\n\nThe Gare Matabiau Train Station is a 12-minute walk from the property and Toulouse-Blagnac Airport is located 6.2 mi away.', 'Wind_Speed__998': 1.96, 'UVI__998': 2.0, 'Wind_Gust__998': 2.01, 'Min_Temp__998': 3.91, 'Rain_Fall__999': 0.81, 'Hotel_URL__999': 'https://www.booking.com/hotel/fr/odalys-appart-39-colombelie.html?aid=304142&label=gen173nr-10CAQoggJCD3NlYXJjaF90b3Vsb3VzZUgzWAR ...
# 2025-08-19 12:12:19,122 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Data loaded successfully into Postgres!

# %% [markdown]
# #### Sanity Check

# %%
# Row count 
n_db = pd.read_sql("SELECT COUNT(*) AS n FROM public.hotel_weather_data", engine)["n"][0]
print("Rows in DB:", n_db, "| Rows in local df:", len(hotel_weather_data))

# Peek a few rows
print(pd.read_sql("SELECT * FROM public.hotel_weather_data LIMIT 5", engine))

# Columns & types
print(pd.read_sql("""
  SELECT column_name, data_type
  FROM information_schema.columns
  WHERE table_schema='public' AND table_name='hotel_weather_data'
  ORDER BY ordinal_position
""", engine))
# Out:
# 2025-08-19 12:26:00,788 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-19 12:26:00,793 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-08-19 12:26:00,829 INFO sqlalchemy.engine.Engine [cached since 825.5s ago] {'table_name': 'SELECT COUNT(*) AS n FROM public.hotel_weather_data', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-08-19 12:26:01,012 INFO sqlalchemy.engine.Engine SELECT COUNT(*) AS n FROM public.hotel_weather_data
# 2025-08-19 12:26:01,014 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 12:26:01,075 INFO sqlalchemy.engine.Engine ROLLBACK
# Rows in DB: 1000 | Rows in local df: 1000
# 2025-08-19 12:26:01,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-19 12:26:01,098 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-08-19 12:26:01,099 INFO sqlalchemy.engine.Engine [cached since 825.8s ago] {'table_name': 'SELECT * FROM public.hotel_weather_data LIMIT 5', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-08-19 12:26:01,137 INFO sqlalchemy.engine.Engine SELECT * FROM public.hotel_weather_data LIMIT 5
# 2025-08-19 12:26:01,138 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 12:26:01,179 INFO sqlalchemy.engine.Engine ROLLBACK
#    City_ID             City                                   Hotel_Name  \
# 0       33  Aix en Provence            Renaissance Aix-en-Provence Hotel
# 1       33  Aix en Provence            Renaissance Aix-en-Provence Hotel
# 2       33  Aix en Provence            Renaissance Aix-en-Provence Hotel
# 3       33  Aix en Provence            Renaissance Aix-en-Provence Hotel
# 4       33  Aix en Provence  Séjours & Affaires Aix-en-Provence Mirabeau
#
#    Number_of_Reviews     Neighborhood  Distance_from_Center  \
# 0               1692  Aix-en-Provence  0.6 km from downtown
# 1               1692  Aix-en-Provence  0.6 km from downtown
# 2               1692  Aix-en-Provence  0.6 km from downtown
# 3               1692  Aix-en-Provence  0.6 km from downtown
# 4               1337  Aix-en-Provence   350 m from downtown
#
#                                          Description  \
# 0  Located within a 10-minute walk of the center ...
# 1  Located within a 10-minute walk of the center ...
# 2  Located within a 10-minute walk of the center ...
# 3  Located within a 10-minute walk of the center ...
# 4  This Séjours & Affaires residence is located i...
#
#                                           Facilities          Address  \
# 0  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 1  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 2  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 3  2 swimming pools, Private Parking, Spa, Free W...  Aix-en-Provence
# 4  Private Parking, Free Wifi, Family rooms, Non-...  Aix-en-Provence
#
#     Latitude  Longitude                                          Hotel_URL  \
# 0  43.526240   5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 1  43.526240   5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 2  43.526240   5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 3  43.526240   5.438205  https://www.booking.com/hotel/fr/renaissance-a...
# 4  43.525241   5.441266  https://www.booking.com/hotel/fr/residence-mir...
#
#    Rate              Weather_Date  \
# 0   8.5 2025-03-02 11:00:00+00:00
# 1   8.5 2025-04-02 11:00:00+00:00
# 2   8.5 2025-05-02 11:00:00+00:00
# 3   8.5 2025-06-02 11:00:00+00:00
# 4   7.9 2025-06-02 11:00:00+00:00
#
#                                      Weather_Summary  Min_Temp  Max_Temp  \
# 0  There will be partly cloudy until morning, the...      6.20     14.63
# 1    Expect a day of partly cloudy with clear spells      6.24     13.58
# 2    Expect a day of partly cloudy with clear spells      5.80     13.91
# 3                      There will be clear sky today      5.99     13.79
# 4                      There will be clear sky today      5.99     13.79
#
#    Average_Min_Temp  Average_Max_Temp  Pressure  Humidity  Dew_Point  \
# 0              6.76          12.96125      1022        48       1.00
# 1              6.76          12.96125      1026        38      -1.77
# 2              6.76          12.96125      1031        43      -0.97
# 3              6.76          12.96125      1028        41      -0.70
# 4              6.76          12.96125      1028        41      -0.70
#
#    Wind_Speed  Wind_Deg  Wind_Gust  Clouds  Avg_Clouds  Pop  Rain  Rain_Fall  \
# 0        1.96       302       2.68       0       54.25  0.0  None      0.595
# 1        2.31       234       2.17      41       54.25  0.0  None      0.595
# 2        1.72       290       2.02       0       54.25  0.0  None      0.595
# 3        2.60       245       2.35       0       54.25  0.0  None      0.595
# 4        2.60       245       2.35       0       54.25  0.0  None      0.595
#
#    Snow   UVI
# 0  None  1.97
# 1  None  1.79
# 2  None  1.88
# 3  None  1.97
# 4  None  1.97
# 2025-08-19 12:26:01,216 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-08-19 12:26:01,217 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-08-19 12:26:01,218 INFO sqlalchemy.engine.Engine [cached since 825.9s ago] {'table_name': "\n  SELECT column_name, data_type\n  FROM information_schema.columns\n  WHERE table_schema='public' AND table_name='hotel_weather_data'\n  ORDER BY ordinal_position\n", 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-08-19 12:26:01,242 INFO sqlalchemy.engine.Engine
#   SELECT column_name, data_type
#   FROM information_schema.columns
#   WHERE table_schema='public' AND table_name='hotel_weather_data'
#   ORDER BY ordinal_position
#
# 2025-08-19 12:26:01,249 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-08-19 12:26:01,270 INFO sqlalchemy.engine.Engine ROLLBACK
#              column_name                 data_type
# 0                City_ID                    bigint
# 1                   City                      text
# 2             Hotel_Name                      text
# 3      Number_of_Reviews                    bigint
# 4           Neighborhood                      text
# 5   Distance_from_Center                      text
# 6            Description                      text
# 7             Facilities                      text
# 8                Address                      text
# 9               Latitude          double precision
# 10             Longitude          double precision
# 11             Hotel_URL                      text
# 12                  Rate          double precision
# 13          Weather_Date  timestamp with time zone
# 14       Weather_Summary                      text
# 15              Min_Temp          double precision
# 16              Max_Temp          double precision
# 17      Average_Min_Temp          double precision
# 18      Average_Max_Temp          double precision
# 19              Pressure                    bigint
# 20              Humidity                    bigint
# 21             Dew_Point          double precision
# 22            Wind_Speed          double precision
# 23              Wind_Deg                    bigint
# 24             Wind_Gust          double precision
# 25                Clouds                    bigint
# 26            Avg_Clouds          double precision
# 27                   Pop          double precision
# 28                  Rain          double precision
# 29             Rain_Fall          double precision
# 30                  Snow          double precision
# 31                   UVI          double precision

# %% [markdown]
# #### Checking connection with datawarehouse

# %% [markdown]
# ##### Connect to the default DB and create the kayak database

# %%
# pip install sqlalchemy psycopg2-binary pandas s3fs boto3

from sqlalchemy import create_engine, text

DBUSER   = "jedha_user"
#DBNAME   = "postgres"
PORT     = 5432
TARGET_DB = "jedha-kayak"    

# connect to the default 'postgres' database
admin_engine = create_engine(
    f"postgresql+psycopg2://{DBUSER}:{DBPASS}@{DBHOST}:{PORT}/postgres?sslmode=require",
    isolation_level="AUTOCOMMIT",   # CREATE DATABASE needs autocommit
    pool_pre_ping=True,
)

with admin_engine.connect() as conn:
    # list databases
    rows = conn.execute(text("SELECT datname FROM pg_database")).fetchall()
    print("Existing DBs:", [r[0] for r in rows])

    # create your DB if missing (the hyphen requires quotes)
    if TARGET_DB not in [r[0] for r in rows]:
        conn.execute(text(f'CREATE DATABASE "{TARGET_DB}" ENCODING \'UTF8\' TEMPLATE template1'))
        print(f'Created database "{TARGET_DB}".')
# Out:
# Existing DBs: ['template0', 'template1', 'postgres', 'rdsadmin']
# Created database "jedha-kayak".

# %% [markdown]
# #### Reconnect to new DB and ping

# %%
from sqlalchemy import create_engine, text

DBUSER, DBPASS = "jedha_user", "Jedha2025!"
DBHOST, PORT   = "jedha-kayak.cxsio8oio4r1.eu-west-3.rds.amazonaws.com", 5432
DBNAME         = "jedha-kayak"  # now exists

engine = create_engine(
    f"postgresql+psycopg2://{DBUSER}:{DBPASS}@{DBHOST}:{PORT}/{DBNAME}?sslmode=require",
    pool_pre_ping=True
)

with engine.connect() as conn:
    print(conn.execute(text("SELECT current_database(), 1")).fetchone())
# Out:
# ('jedha-kayak', 1)
